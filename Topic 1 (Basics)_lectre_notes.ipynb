# %%
import numpy as np

# %% [markdown]
# **Example (functions)**

# %%
def f(x):
    return 2*x

# %%
f(3)
# Out:
# 6

# %% [markdown]
# **Example (vectors)**

# %%
# operation "+" on built-in and numpy vectors
x = [1,2,3]
y = [-1, 1, -1]
x+y
type(x)

x = np.array([1,2,3])
y = np.array([-1,1,-1])
x+y
# Out:
# array([0, 3, 2])

# %% [markdown]
# **Example (dataframes)**

# %%
import pandas as pd

# %%
# specify rows
row_1 = [1, 0.5]
row_2 = [3, 0.25]

table = pd.DataFrame(data = [row_1, row_2], columns = ["Mean", "Stdev"])
table
# Out:
#    Mean  Stdev
# 0     1   0.50
# 1     3   0.25

# %%
# specify columns
d = {'Mean': [1, 3], 'Stdev': [0.5, 0.25]}
table = pd.DataFrame(data=d)
table
# Out:
#    Mean  Stdev
# 0     1   0.50
# 1     3   0.25

# %%
google_data = pd.read_csv('Topic 1 (Basics)_data.csv')
google_data
# type(google_data)
# Out:
#      symbol                       date        open        high         low  \
# 0      GOOG                 2004-08-19    2.490664    2.591785    2.390042
# 1      GOOG                 2004-08-20    2.515820    2.716817    2.503118
# 2      GOOG                 2004-08-23    2.758411    2.826406    2.716070
# 3      GOOG                 2004-08-24    2.770615    2.779581    2.579581
# 4      GOOG                 2004-08-25    2.614201    2.689918    2.587302
# ...     ...                        ...         ...         ...         ...
# 5322   GOOG                 2025-10-14  241.755005  248.024994  241.177994
# 5323   GOOG                 2025-10-15  248.085007  252.759995  246.789993
# 5324   GOOG                 2025-10-16  252.464996  257.579987  250.669998
# 5325   GOOG                 2025-10-17  251.350006  254.880005  248.589996
# 5326   GOOG  2025-10-20 15:30:16-04:00  255.160004  257.869995  254.600006
#
#            close     volume    adjclose  dividends  splits
# ...

# %%
# access by column
google_data['close']
# access by row
google_data.iloc[1]
# Out:
# symbol             GOOG
# date         2004-08-20
# open            2.51582
# high           2.716817
# low            2.503118
# close          2.697639
# volume        458857488
# adjclose       2.679304
# dividends           0.0
# splits              0.0
# Name: 1, dtype: object

# %% [markdown]
# Dynamic data upload

# %%
from yahooquery import Ticker

# %% [markdown]
# pip install yahooquery

# %% [markdown]
# https://yahooquery.dpguthrie.com/<br>
# https://yahooquery.dpguthrie.com/guide/ticker/historical/

# %%
snp = Ticker('^GSPC')
snp_data = snp.history(start='2009-01-01', interval = '1d')
snp_data
# snp_data.columns
# snp_data.index
# Out:
#                           open         high          low        close  \
# symbol date
# ^GSPC  2009-01-02   902.989990   934.729980   899.349976   931.799988
#        2009-01-05   929.169983   936.630005   919.530029   927.450012
#        2009-01-06   931.169983   943.849976   927.280029   934.700012
#        2009-01-07   927.450012   927.450012   902.369995   906.650024
#        2009-01-08   905.729980   910.000000   896.809998   909.729980
# ...                        ...          ...          ...          ...
#        2026-01-14  6937.410156  6941.299805  6885.740234  6926.600098
#        2026-01-15  6969.459961  6979.339844  6937.930176  6944.470215
#        2026-01-16  6960.540039  6967.299805  6925.089844  6940.009766
#        2026-01-20  6865.240234  6871.169922  6789.049805  6796.859863
#        2026-01-21  6810.709961  6910.390137  6804.959961  6875.620117
#
#                        volume     adjclose
# symbol date
# ^GSPC  2009-01-02  4048270000   931.799988
# ...

# %%
snp_data.index
# get data

prices = snp_data['close']
dates = snp_data.index.get_level_values(1)

# %%
import plotly.graph_objects as go

# %% [markdown]
# **Example (Graphs)**

# %%
# Scatterplot
graph = go.Figure()

scatter = go.Scatter(x = dates, y = prices)
graph.add_trace(scatter)

graph.show()
# Out:
# <div>                            <div id="de3c3400-f85f-4a26-a6c0-b3473ab24f88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de3c3400-f85f-4a26-a6c0-b3473ab24f88")) {                    Plotly.newPlot(                        "de3c3400-f85f-4a26-a6c0-b3473ab24f88",                        [{"x":["2009-01-02","2009-01-05","2009-01-06","2009-01-07","2009-01-08","2009-01-09","2009-01-12","2009-01-13","2009-01-14","2009-01-15","2009-01-16","2009-01-20","2009-01-21","2009-01-22","2009-01-23","2009-01-26","2009-01-27","2009-01-28","2009-01-29","2009-01-30","2009-02-02","2009-02-03","2009-02-04","2009-02-05","2009-02-06","2009-02-09","2009-02-10","2009-02-11","2009-02-12","2009-02-13","2009-02-17","2009-02-18","2009-02-19","2009-02-20","2009-02-23","2009-
# ...

# %%
# Histogram
graph = go.Figure()
hist = go.Histogram(x = prices, histnorm = 'probability density', nbinsx = 60)
graph.add_trace(hist)
graph.show()
# Out:
# <div>                            <div id="6c43f883-763c-411b-b2ad-943d9cf40f53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c43f883-763c-411b-b2ad-943d9cf40f53")) {                    Plotly.newPlot(                        "6c43f883-763c-411b-b2ad-943d9cf40f53",                        [{"histnorm":"probability density","nbinsx":60,"x":[931.7999877929688,927.4500122070312,934.7000122070312,906.6500244140625,909.72998046875,890.3499755859375,870.260009765625,871.7899780273438,842.6199951171875,843.739990234375,850.1199951171875,805.219970703125,840.239990234375,827.5,831.9500122070312,836.5700073242188,845.7100219726562,874.0900268554688,845.1400146484375,825.8800048828125,825.4400024414062,838.510009765625,832.22998046875,845.8499755859375,868.5
# ...
